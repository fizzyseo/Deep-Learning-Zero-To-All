# %% [markdown]
# # Lab-11-2-1 RNN hihello

# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %%
sample = " if you want you"

# %%
# make dictionary
char_set = list(set(sample))
char_dic = {c: i for i, c in enumerate(char_set)}
print(char_dic)
# Out:
# {'a': 0, 'w': 1, 'n': 2, 'i': 3, ' ': 4, 'y': 5, 'f': 6, 'u': 7, 'o': 8, 't': 9}

# %%
# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
learning_rate = 0.1

# %%
# data setting
sample_idx = [char_dic[c] for c in sample]
x_data = [sample_idx[:-1]]
x_one_hot = [np.eye(dic_size)[x] for x in x_data]
y_data = [sample_idx[1:]]

# %%
# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)
# Out:
# <ipython-input-7-52579379b225>:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   X = torch.FloatTensor(x_one_hot)

# %%
# declare RNN
rnn = torch.nn.RNN(dic_size, hidden_size, batch_first=True)

# %%
# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), learning_rate)

# %%
# start training
for i in range(50):
    optimizer.zero_grad()
    outputs, _status = rnn(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    result = outputs.data.numpy().argmax(axis=2)
    result_str = ''.join([char_set[c] for c in np.squeeze(result)])
    print(i, "loss: ", loss.item(), "prediction: ", result, "true Y: ", y_data, "prediction str: ", result_str)
# Out:
# 0 loss:  2.2267870903015137 prediction:  [[5 7 8 8 7 8 1 7 8 5 8 6 5 7 8]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yuoouowuoyofyuo
# 1 loss:  1.9754974842071533 prediction:  [[8 7 4 8 8 7 4 5 8 7 7 6 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  ou oou youufyou
# 2 loss:  1.7197563648223877 prediction:  [[5 7 4 5 8 7 4 1 0 0 7 4 5 0 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yu you waau yau
# 3 loss:  1.5662310123443604 prediction:  [[5 6 4 5 8 7 4 1 0 2 9 4 5 0 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you want yau
# 4 loss:  1.4562528133392334 prediction:  [[5 6 4 5 8 7 4 5 0 4 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you ya t you
# 5 loss:  1.3756920099258423 prediction:  [[5 6 4 5 8 7 4 5 0 4 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you ya t you
# 6 loss:  1.313658595085144 prediction:  [[5 6 4 5 8 7 4 5 8 4 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you yo t you
# 7 loss:  1.252845048904419 prediction:  [[5 6 4 5 8 7 4 5 8 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you yont you
# 8 loss:  1.173923134803772 prediction:  [[5 6 4 5 8 7 4 5 8 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you yont you
# 9 loss:  1.1359747648239136 prediction:  [[5 6 4 5 8 7 4 5 8 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you yont you
# 10 loss:  1.1049275398254395 prediction:  [[5 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  yf you yant you
# 11 loss:  1.0838340520858765 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 12 loss:  1.0430443286895752 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 13 loss:  1.01222825050354 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 14 loss:  0.9927991628646851 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 15 loss:  0.9733994603157043 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 16 loss:  0.9656021595001221 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 17 loss:  0.9467562437057495 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 18 loss:  0.9339488744735718 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 19 loss:  0.92377108335495 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 20 loss:  0.9162061214447021 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 21 loss:  0.9101201295852661 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 22 loss:  0.9010389447212219 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 23 loss:  0.8920027613639832 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 24 loss:  0.8853281736373901 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 25 loss:  0.8787940740585327 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 26 loss:  0.8722858428955078 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 27 loss:  0.867304265499115 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 28 loss:  0.864057183265686 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 29 loss:  0.861312210559845 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 30 loss:  0.8584322333335876 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 31 loss:  0.8561208844184875 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 32 loss:  0.8543242812156677 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 33 loss:  0.8525296449661255 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 34 loss:  0.8506773710250854 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 35 loss:  0.8491633534431458 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 36 loss:  0.8480613827705383 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 37 loss:  0.846809446811676 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 38 loss:  0.8456365466117859 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 39 loss:  0.8448468446731567 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 40 loss:  0.844083845615387 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 41 loss:  0.8432090878486633 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 42 loss:  0.8424800038337708 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 43 loss:  0.8418883085250854 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 44 loss:  0.8411480188369751 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 45 loss:  0.8404844403266907 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 46 loss:  0.8399912118911743 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 47 loss:  0.8394644260406494 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 48 loss:  0.8389347791671753 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
# 49 loss:  0.8385588526725769 prediction:  [[3 6 4 5 8 7 4 5 0 2 9 4 5 8 7]] true Y:  [[3, 6, 4, 5, 8, 7, 4, 1, 0, 2, 9, 4, 5, 8, 7]] prediction str:  if you yant you
